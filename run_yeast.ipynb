# %%
import pandas as pd
import numpy as np
from model.booster import GBDT_Muti
from model.dataset import DataSet
from model.configs import Configs

# %%
x_train = np.load('data/yeast/yeast_traindata.npy')
y_train = np.load('data/yeast/yeast_trainlabel.npy')
x_test = np.load('data/yeast/yeast_testdata.npy')
y_test = np.load('data/yeast/yeast_testlabel.npy')

# %%
y_train.shape
# Out:
# (1554, 4)

# %%
x_train.shape
# Out:
# (1554, 103)

# %%
dataset_name = 'yeast'
dataset_train = DataSet(x_train, y_train)
dataset_test = DataSet(x_test, y_test)
configs = Configs('configs/configs_{}.json'.format(dataset_name))

# %%
gbdt = GBDT_Muti(configs)
gbdt.fit(dataset_train,dataset_test)
# Out:
# iter1 : valid loss=2.499250
# iter1 : train loss=2.216114
# iter2 : valid loss=2.169503
# iter2 : train loss=1.941331
# iter3 : valid loss=1.903361
# iter3 : train loss=1.714587
# iter4 : valid loss=1.687022
# iter4 : train loss=1.529630
# iter5 : valid loss=1.510427
# iter5 : train loss=1.377527
# iter6 : valid loss=1.363638
# iter6 : train loss=1.254239
# iter7 : valid loss=1.246302
# iter7 : train loss=1.151269
# iter8 : valid loss=1.147688
# iter8 : train loss=1.066252
# iter9 : valid loss=1.067579
# iter9 : train loss=0.995795
# iter10 : valid loss=1.001115
# iter10 : train loss=0.938116
# iter11 : valid loss=0.949619
# iter11 : train loss=0.890353
# iter12 : valid loss=0.906476
# iter12 : train loss=0.850315
# iter13 : valid loss=0.869650
# iter13 : train loss=0.816899
# iter14 : valid loss=0.840697
# iter14 : train loss=0.787974
# iter15 : valid loss=0.816493
# iter15 : train loss=0.764273
# iter16 : valid loss=0.795710
# iter16 : train loss=0.744951
# iter17 : valid loss=0.779447
# iter17 : train loss=0.728036
# iter18 : valid loss=0.767391
# iter18 : train loss=0.713769
# iter19 : valid loss=0.756502
# iter19 : train loss=0.701971
# iter20 : valid loss=0.747115
# iter20 : train loss=0.691021
# iter21 : valid loss=0.739955
# iter21 : train loss=0.681560
# iter22 : valid loss=0.732877
# iter22 : train loss=0.673345
# iter23 : valid loss=0.727312
# iter23 : train loss=0.665664
# iter24 : valid loss=0.722466
# iter24 : train loss=0.659501
# iter25 : valid loss=0.719485
# iter25 : train loss=0.654140
# iter26 : valid loss=0.715933
# iter26 : train loss=0.648104
# iter27 : valid loss=0.713042
# iter27 : train loss=0.644336
# iter28 : valid loss=0.710275
# iter28 : train loss=0.639671
# iter29 : valid loss=0.708822
# iter29 : train loss=0.635064
# iter30 : valid loss=0.706292
# iter30 : train loss=0.630782
# iter31 : valid loss=0.704696
# iter31 : train loss=0.626357
# iter32 : valid loss=0.703390
# iter32 : train loss=0.622446
# iter33 : valid loss=0.701414
# iter33 : train loss=0.618332
# iter34 : valid loss=0.700383
# iter34 : train loss=0.615809
# iter35 : valid loss=0.698290
# iter35 : train loss=0.612451
# iter36 : valid loss=0.696479
# iter36 : train loss=0.608374
# iter37 : valid loss=0.695379
# iter37 : train loss=0.606237
# iter38 : valid loss=0.694271
# iter38 : train loss=0.603301
# iter39 : valid loss=0.692385
# iter39 : train loss=0.600569
# iter40 : valid loss=0.692540
# Early stop at iter 40

# %%
pred_prob = gbdt.predict_set_prob(dataset_test.X)
pred_labels = gbdt.predict_set_label(dataset_test.X)

# %%
pred_prob_df = pd.DataFrame(pred_prob)
pred_labels_df = pd.DataFrame(pred_labels)
pred_prob_df.to_csv('./result/he_pred_prob.csv', index=False)
pred_labels_df.to_csv('./result/he_pred_label.csv', index=False)

# %%
pred_labels_df
# Out:
#      0  1  2  3
# 0    1  1  0  0
# 1    1  1  0  0
# 2    1  1  0  0
# 3    1  1  0  1
# 4    1  1  0  0
# ..  .. .. .. ..
# 662  1  1  0  1
# 663  1  1  0  0
# 664  1  1  0  0
# 665  1  1  0  0
# 666  1  1  0  1
#
# [667 rows x 4 columns]

# %%
from sklearn.metrics import accuracy_score, f1_score, hamming_loss

# %%
f1_score_macro = f1_score(y_test, pred_labels_df, average='macro')
f1_score_macro
# Out:
# 0.5980963494263093

# %%
f1_score_micro = f1_score(y_test, pred_labels_df, average='micro')
f1_score_micro
# Out:
# 0.7540453074433657

# %%
acc = accuracy_score(y_test, pred_labels_df)
acc
# Out:
# 0.3733133433283358

# %%
ham = hamming_loss(y_test, pred_labels_df)
ham
# Out:
# 0.2848575712143928

# %%
record = pd.read_csv('record.csv')
record
# Out:
#    dataset  learn_rate  max_depth  stop_iter  f1_score_macro  f1_score_micro  \
# 0       he         0.5          3         12        0.369850        0.667254
# 1       he         0.1          3         49        0.398767        0.714405
# 2       he         0.3          3         23        0.380834        0.702929
# 3       he         0.8          4         10        0.418323        0.731984
# 4       he         0.8          3         10        0.422834        0.728595
# 5       re         0.1          3         95        0.623452        0.847726
# 6       he         1.0          3          5        0.441586        0.738654
# 7       re         0.5          3         23        0.646683        0.843501
# 8       re         0.8          3         10        0.640336        0.842587
# 9       re         0.8          4         17        0.681009        0.838966
# 10      re         1.0          4          9        0.684589        0.848168
# 11      re         1.0          3         17        0.694317        0.845745
# 12      re         0.3          3         36        0.608421        0.840183
# 13      he         1.2          3          6        0.401669        0.729017
# 14      re         1.2          3         14        0.725101        0.855663
# 15      re         1.4          3         11        0.691354        0.857695
# 16      he         1.0          2          5        0.416609        0.733229
# 17      re         1.0          2          7        0.600619        0.829523
# 18      he         1.0          4          4        0.421018        0.733229
# 19      re         1.0          4         14        0.706548        0.862001
# 20      he         1.0          5          6        0.462285        0.742448
# 21      re         1.0          5          8        0.700084        0.849476
# 22      he         1.0          6          5        0.452182        0.716491
# 23      re         1.0          6          6        0.689287        0.851511
# 24      he         1.0          7          5        0.448898        0.724756
# 25      re         1.0          7          9        0.700163        0.831894
# 26      he         1.0          8          4        0.432355        0.728424
# 27      re         1.0          8          5        0.609133        0.822006
# 28   yeast         1.0          5          5        0.264135        0.539694
# 29   yeast         0.5          3         17        0.220897        0.462711
# 30   yeast         0.8          8          8        0.295294        0.500000
# 31   yeast         0.8          5          4        0.613792        0.720052
# 32   yeast         1.0          3          3        0.609702        0.756334
# 33   yeast         0.5          8          8        0.613628        0.704825
#
#          acc       ham
# 0   0.531667  0.157500
# 1   0.598333  0.142917
# 2   0.578333  0.147917
# 3   0.615000  0.137917
# 4   0.610000  0.140000
# 5   0.686667  0.096250
# 6   0.631667  0.139167
# 7   0.676667  0.098333
# 8   0.675000  0.100417
# 9   0.658333  0.101250
# 10  0.685000  0.096667
# 11  0.683333  0.096667
# 12  0.683333  0.102083
# 13  0.616667  0.141250
# 14  0.696667  0.092917
# 15  0.706667  0.092083
# 16  0.630000  0.142500
# 17  0.663333  0.108750
# 18  0.630000  0.142500
# 19  0.700000  0.087917
# 20  0.626667  0.135000
# 21  0.688333  0.095833
# 22  0.591667  0.145417
# 23  0.683333  0.094167
# 24  0.610000  0.140833
# 25  0.653333  0.105417
# 26  0.620000  0.142917
# 27  0.646667  0.114583
# 28  0.088729  0.221480
# 29  0.052758  0.229531
# 30  0.091127  0.226447
# 31  0.311844  0.322339
# 32  0.347826  0.291979
# 33  0.334333  0.332459

# %%
record = record.append([{
    "dataset": dataset_name,
    "learn_rate": configs.learn_rate,
    "max_depth": configs.max_depth,
    "stop_iter": gbdt.stop_iter,
    "f1_score_macro":f1_score_macro,
    "f1_score_micro":f1_score_micro,
    "acc":acc,
    "ham":ham
    }])
record.to_csv('record.csv', index=False)
